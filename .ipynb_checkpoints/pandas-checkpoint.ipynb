# %%
b=open('datass.csv','w')
b.close()

# %%
import pandas as pd
df=pd.read_csv('datass.csv')
df
# Out:
#    sn     name  age  address  phone
# 0   1      ram   78      ktm    887
# 1   2     haru   78      ktm    887
# 2   3    shyam   78      ktm    887
# 3   4     rita   78      bkt    887
# 4   5  narayan   78  pokhara     88
# 5   6    ramuu   78      ktm     88

# %%
print(df.head())
# Out:
#    sn     name  age  address  phone
# 0   1      ram   78      ktm    887
# 1   2     haru   78      ktm    887
# 2   3    shyam   78      ktm    887
# 3   4     rita   78      bkt    887
# 4   5  narayan   78  pokhara     88

# %%
df.iloc[3:5]
# Out:
#    sn     name  age  address  phone
# 3   4     rita   78      bkt    887
# 4   5  narayan   78  pokhara     88

# %%
import pandas as pd
df=pd.read_csv('datass.csv',index_col='sn')                  #index_col is unique value
df
# Out:
#        name  age  address  phone
# sn
# 1       ram   78      ktm    887
# 2      haru   78      ktm    887
# 3     shyam   78      ktm    887
# 4      rita   78      bkt    887
# 5   narayan   78  pokhara     88
# 6     ramuu   78      ktm     88

# %%
import pandas as pd
df=pd.read_csv('datass.csv',index_col='sn')                  #index_col is unique value
df.loc[2:5]
# Out:
#        name  age  address  phone
# sn
# 2      haru   78      ktm    887
# 3     shyam   78      ktm    887
# 4      rita   78      bkt    887
# 5   narayan   78  pokhara     88

# %%
import pandas as pd
df=pd.read_csv('datass.csv',index_col='name')                 
df['rita':'ramuu']
# Out:
#          sn  age  address  phone
# name
# rita      4   78      bkt    887
# narayan   5   78  pokhara     88
# ramuu     6   78      ktm     88

# %%
import pandas as pd
df=pd.read_csv('datass.csv',index_col='sn')                  
df['name']
# Out:
# sn
# 1        ram
# 2       haru
# 3      shyam
# 4       rita
# 5    narayan
# 6      ramuu
# Name: name, dtype: object

# %%
import pandas as pd
df=pd.read_csv('datass.csv',index_col='sn')                  
df['address']=="ktm"
# Out:
# sn
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6     True
# Name: address, dtype: bool

# %%
import pandas as pd
df=pd.read_csv('datass.csv',index_col='sn')                  
df[df['address']=="ktm"]
# Out:
#      name  age address  phone
# sn
# 1     ram   78     ktm    887
# 2    haru   78     ktm    887
# 3   shyam   78     ktm    887
# 6   ramuu   78     ktm     88

# %%
import pandas as pd
df=pd.read_csv('datass.csv',index_col='sn')                  
df[df['age']>70]
# Out:
#        name  age  address  phone
# sn
# 1       ram   78      ktm    887
# 2      haru   78      ktm    887
# 3     shyam   78      ktm    887
# 4      rita   78      bkt    887
# 5   narayan   78  pokhara     88
# 6     ramuu   78      ktm     88

# %%
import pandas as pd
df=pd.read_csv('datass.csv',index_col='sn')                  
data=df[(df['age']>70)&(df['age']<80)]
data.to_csv('new_datass.csv')

# %%
import pandas as pd
data={'name':['ram','shyam','hari'],
      'age':[4,5,6],
     }
df=pd.DataFrame(data)
df
# Out:
#     name  age
# 0    ram    4
# 1  shyam    5
# 2   hari    6

# %%
import csv
data=[['name','age','address'],
     ['ram',34,'ktm'],
     ['ramrita',54,'bkt'],
     ['sarita',54,'lalitpur']]
f=open('list_data.csv','w')     
x=csv.writer(f)
for i in data:
    x.writerow(i)

    
f.close()

# %%
import pandas as pd
df=pd.read_csv('list_data.csv')
df
# Out:
#       name  age   address
# 0      ram   34       ktm
# 1  ramrita   54       bkt
# 2   sarita   54  lalitpur
